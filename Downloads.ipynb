# %%
# !pip install -r requirements.txt

# %%
# !pip install streamlit-jupyter
# Out:
# ...
#
#    ---------------------------- ----------- 5/7 [stqdm]
#    ---------------------------------------- 7/7 [streamlit-jupyter]
#
# ...

# %% [markdown]
# C:\Users\amith\LipNet\app inside app folder i have my streamlit application streamlitapp.py
#
# 1. Open the Anacoda terminal and navigate to that directory by using: cd C:\Users\amith\LipNet\app
# 2. Then type: streamlit run streamlitapp.py

# %%
#pip install ipynb-py-convert
ipynb-py-convert \
C:\Users\Clive\Clive Folder\Imperial\Academics\CIVE70111 - Machine Learning\Coursework\Streamlit\build-with-ai-ai-powered-dashboards-with-streamlit-4031444\Chapter_1.ipynb C:\Users\Clive\Clive Folder\Imperial\Academics\CIVE70111 - Machine Learning\Coursework\Streamlit\build-with-ai-ai-powered-dashboards-with-streamlit-4031444\Chapter_1.py
